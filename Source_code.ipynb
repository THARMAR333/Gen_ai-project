# %% [markdown]
# <a href="https://colab.research.google.com/github/THARMAR333/Gen_ai-project/blob/main/Source_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    "user": ["A", "B", "C", "D", "E"],
    "login_time": [9, 23, 14, 2, 18],
    "activity": ["normal", "download", "normal", "idle", "normal"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   user  login_time  activity
# 0    A           9    normal
# 1    B          23  download
# 2    C          14    normal
# 3    D           2      idle
# 4    E          18    normal

# %%
def behavior_agent(row):
    if row["login_time"] < 6 or row["login_time"] > 22:
        return "⚠️ Anomaly"
    return "✅ Normal"

# %%
def decision_agent(row):
    if row["login_time"] < 3:
        return "High Risk 🚨"
    elif row["login_time"] < 6 or row["login_time"] > 22:
        return "Medium Risk ⚠️"
    else:
        return "Low Risk ✅"

# %%
def action_agent(row):
    if row["risk"] == "High Risk 🚨":
        return "🚫 Block User + Send Alert"
    elif row["risk"] == "Medium Risk ⚠️":
        return "📧 Send Warning"
    else:
        return "No Action"

# %%
df["status"] = df.apply(behavior_agent, axis=1)
df["risk"] = df.apply(decision_agent, axis=1)
df["action"] = df.apply(action_agent, axis=1)

print(df)
# Out:
#   user  login_time  activity      status            risk  \
# 0    A           9    normal    ✅ Normal      Low Risk ✅
# 1    B          23  download  ⚠️ Anomaly  Medium Risk ⚠️
# 2    C          14    normal    ✅ Normal      Low Risk ✅
# 3    D           2      idle  ⚠️ Anomaly     High Risk 🚨
# 4    E          18    normal    ✅ Normal      Low Risk ✅
#
#                       action
# 0                  No Action
# 1             📧 Send Warning
# 2                  No Action
# 3  🚫 Block User + Send Alert
# 4                  No Action

# %%
df.to_csv("output.csv", index=False)

# %%
new_df = pd.read_csv("output.csv")
print(new_df)
# Out:
#   user  login_time  activity      status            risk  \
# 0    A           9    normal    ✅ Normal      Low Risk ✅
# 1    B          23  download  ⚠️ Anomaly  Medium Risk ⚠️
# 2    C          14    normal    ✅ Normal      Low Risk ✅
# 3    D           2      idle  ⚠️ Anomaly     High Risk 🚨
# 4    E          18    normal    ✅ Normal      Low Risk ✅
#
#                       action
# 0                  No Action
# 1             📧 Send Warning
# 2                  No Action
# 3  🚫 Block User + Send Alert
# 4                  No Action

# %%
import matplotlib.pyplot as plt

# %%
status_counts = df["status"].value_counts()

plt.figure()
status_counts.plot(kind='bar')
plt.title("User Behavior Analysis")
plt.xlabel("Status")
plt.ylabel("Count")

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9989 (\N{WHITE HEAVY CHECK MARK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
risk_counts = df["risk"].value_counts()

plt.figure()
risk_counts.plot(kind='bar')
plt.title("Risk Level Distribution")
plt.xlabel("Risk Level")
plt.ylabel("Number of Users")

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9989 (\N{WHITE HEAVY CHECK MARK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128680 (\N{POLICE CARS REVOLVING LIGHT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure()
plt.hist(df["login_time"])
plt.title("Login Time Distribution")
plt.xlabel("Login Time")
plt.ylabel("Frequency")

plt.show()

# %%
grouped = df.groupby("risk").size()

plt.figure()
grouped.plot(kind='bar')
plt.title("Risk vs User Count")

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128680 (\N{POLICE CARS REVOLVING LIGHT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9989 (\N{WHITE HEAVY CHECK MARK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
